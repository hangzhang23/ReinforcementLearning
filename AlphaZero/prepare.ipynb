# %% [markdown]
# 挂载drive

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import os
os.chdir('/content/drive/My Drive/AlphaZero_test')

# %%
# !ls
# Out:
# best_policy.model     human_play.py	 policy_value_net_pytorch.py  train.py
# current_policy.model  mcts_alphaZero.py  prepare.ipynb
# game.py		      mcts_pure.py	 __pycache__

# %% [markdown]
# 运行Alpha_zero

# %%
# !python train.py
# Out:
# /content/drive/My Drive/AlphaZero_test/policy_value_net_pytorch.py:45: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   x_act = F.log_softmax(self.act_fc1(x_act))
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1698: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# batch i:1, episode_len:17
# batch i:2, episode_len:25
# batch i:3, episode_len:22
# batch i:4, episode_len:34
# kl:0.01197,lr_multiplier:1.000,loss:5.574480056762695,entropy:4.597117900848389,explained_var_old:0.000,explained_var_new:0.023
# batch i:5, episode_len:13
# kl:0.01397,lr_multiplier:1.000,loss:5.586081504821777,entropy:4.58767032623291,explained_var_old:0.003,explained_var_new:0.010
# batch i:6, episode_len:10
# kl:0.00592,lr_multiplier:1.500,loss:5.529818058013916,entropy:4.581352710723877,explained_var_old:0.011,explained_var_new:0.071
# batch i:7, episode_len:13
# kl:0.00632,lr_multiplier:2.250,loss:5.329543590545654,entropy:4.563885688781738,explained_var_old:0.026,explained_var_new:0.343
# batch i:8, episode_len:17
# kl:0.01148,lr_multiplier:2.250,loss:5.222995758056641,entropy:4.58821964263916,explained_var_old:0.311,explained_var_new:0.378
# batch i:9, episode_len:36
# kl:0.02735,lr_multiplier:2.250,loss:5.364937782287598,entropy:4.53158712387085,explained_var_old:0.094,explained_var_new:0.201
# batch i:10, episode_len:29
# kl:0.03800,lr_multiplier:2.250,loss:5.191147804260254,entropy:4.446063995361328,explained_var_old:0.085,explained_var_new:0.328
# batch i:11, episode_len:12
# kl:0.06038,lr_multiplier:1.500,loss:5.047788619995117,entropy:4.4081573486328125,explained_var_old:0.249,explained_var_new:0.465
# batch i:12, episode_len:20
# kl:0.02325,lr_multiplier:1.500,loss:5.119157791137695,entropy:4.474476337432861,explained_var_old:0.179,explained_var_new:0.342
# batch i:13, episode_len:18
# kl:0.01924,lr_multiplier:1.500,loss:4.9782819747924805,entropy:4.451813220977783,explained_var_old:0.332,explained_var_new:0.455
# batch i:14, episode_len:28
# kl:0.03333,lr_multiplier:1.500,loss:4.866922855377197,entropy:4.284426689147949,explained_var_old:0.301,explained_var_new:0.472
# batch i:15, episode_len:29
# kl:0.04162,lr_multiplier:1.000,loss:5.029905796051025,entropy:4.258408069610596,explained_var_old:0.150,explained_var_new:0.287
# batch i:16, episode_len:24
# kl:0.02158,lr_multiplier:1.000,loss:5.0394134521484375,entropy:4.400358200073242,explained_var_old:0.210,explained_var_new:0.308
# batch i:17, episode_len:7
# kl:0.00929,lr_multiplier:1.500,loss:4.957291603088379,entropy:4.30914306640625,explained_var_old:0.234,explained_var_new:0.365
# batch i:18, episode_len:21
# kl:0.03497,lr_multiplier:1.500,loss:4.896628379821777,entropy:4.298027038574219,explained_var_old:0.262,explained_var_new:0.439
# batch i:19, episode_len:28
# kl:0.02429,lr_multiplier:1.500,loss:4.844932556152344,entropy:4.347033500671387,explained_var_old:0.270,explained_var_new:0.493
# batch i:20, episode_len:33
# kl:0.02297,lr_multiplier:1.500,loss:4.738663196563721,entropy:4.3598785400390625,explained_var_old:0.426,explained_var_new:0.596
# batch i:21, episode_len:32
# kl:0.02573,lr_multiplier:1.500,loss:4.728549480438232,entropy:4.3368144035339355,explained_var_old:0.414,explained_var_new:0.612
# batch i:22, episode_len:15
# kl:0.03421,lr_multiplier:1.500,loss:4.530107498168945,entropy:4.262913227081299,explained_var_old:0.538,explained_var_new:0.722
# batch i:23, episode_len:29
# kl:0.03908,lr_multiplier:1.500,loss:4.571748733520508,entropy:4.246728420257568,explained_var_old:0.523,explained_var_new:0.665
# batch i:24, episode_len:38
# kl:0.04000,lr_multiplier:1.500,loss:4.723161697387695,entropy:4.329248428344727,explained_var_old:0.387,explained_var_new:0.583
# batch i:25, episode_len:29
# kl:0.04074,lr_multiplier:1.000,loss:4.700746536254883,entropy:4.286777496337891,explained_var_old:0.358,explained_var_new:0.548
# batch i:26, episode_len:16
# kl:0.01505,lr_multiplier:1.000,loss:4.712402820587158,entropy:4.241145610809326,explained_var_old:0.320,explained_var_new:0.517
# batch i:27, episode_len:21
# kl:0.02054,lr_multiplier:1.000,loss:4.607515335083008,entropy:4.197281837463379,explained_var_old:0.415,explained_var_new:0.592
# batch i:28, episode_len:26
# kl:0.01543,lr_multiplier:1.000,loss:4.638739109039307,entropy:4.173093318939209,explained_var_old:0.415,explained_var_new:0.544
# batch i:29, episode_len:33
# kl:0.02089,lr_multiplier:1.000,loss:4.648926258087158,entropy:4.235594272613525,explained_var_old:0.418,explained_var_new:0.550
# batch i:30, episode_len:25
# kl:0.01255,lr_multiplier:1.000,loss:4.692349910736084,entropy:4.2566633224487305,explained_var_old:0.420,explained_var_new:0.566
# batch i:31, episode_len:14
# kl:0.01688,lr_multiplier:1.000,loss:4.610677242279053,entropy:4.166418552398682,explained_var_old:0.435,explained_var_new:0.559
# batch i:32, episode_len:18
# kl:0.01725,lr_multiplier:1.000,loss:4.6394195556640625,entropy:4.213192939758301,explained_var_old:0.377,explained_var_new:0.553
# batch i:33, episode_len:26
# kl:0.02079,lr_multiplier:1.000,loss:4.52636194229126,entropy:4.097002983093262,explained_var_old:0.454,explained_var_new:0.596
# batch i:34, episode_len:34
# kl:0.02516,lr_multiplier:1.000,loss:4.7295098304748535,entropy:4.13716983795166,explained_var_old:0.260,explained_var_new:0.419
# batch i:35, episode_len:32
# kl:0.03009,lr_multiplier:1.000,loss:4.516169548034668,entropy:4.170661926269531,explained_var_old:0.441,explained_var_new:0.604
# batch i:36, episode_len:29
# kl:0.01971,lr_multiplier:1.000,loss:4.6086626052856445,entropy:4.123869895935059,explained_var_old:0.392,explained_var_new:0.547
# batch i:37, episode_len:27
# kl:0.02278,lr_multiplier:1.000,loss:4.49908447265625,entropy:4.117696762084961,explained_var_old:0.391,explained_var_new:0.579
# batch i:38, episode_len:32
# kl:0.02261,lr_multiplier:1.000,loss:4.469013214111328,entropy:4.063358306884766,explained_var_old:0.426,explained_var_new:0.611
# batch i:39, episode_len:32
# kl:0.02559,lr_multiplier:1.000,loss:4.511572360992432,entropy:4.161815643310547,explained_var_old:0.446,explained_var_new:0.625
# batch i:40, episode_len:22
# kl:0.02465,lr_multiplier:1.000,loss:4.465092182159424,entropy:4.05104923248291,explained_var_old:0.438,explained_var_new:0.623
# batch i:41, episode_len:21
# kl:0.02045,lr_multiplier:1.000,loss:4.48585844039917,entropy:4.1320109367370605,explained_var_old:0.478,explained_var_new:0.626
# batch i:42, episode_len:20
# kl:0.01804,lr_multiplier:1.000,loss:4.457005977630615,entropy:4.085980415344238,explained_var_old:0.482,explained_var_new:0.617
# batch i:43, episode_len:18
# kl:0.01994,lr_multiplier:1.000,loss:4.431580066680908,entropy:4.1336517333984375,explained_var_old:0.557,explained_var_new:0.688
# batch i:44, episode_len:26
# kl:0.02451,lr_multiplier:1.000,loss:4.4433393478393555,entropy:4.101670265197754,explained_var_old:0.499,explained_var_new:0.664
# batch i:45, episode_len:31
# kl:0.01537,lr_multiplier:1.000,loss:4.364365577697754,entropy:4.034463882446289,explained_var_old:0.530,explained_var_new:0.691
# batch i:46, episode_len:14
# kl:0.02946,lr_multiplier:1.000,loss:4.343297958374023,entropy:4.037467956542969,explained_var_old:0.559,explained_var_new:0.690
# batch i:47, episode_len:13
# kl:0.03913,lr_multiplier:1.000,loss:4.3240461349487305,entropy:4.033149719238281,explained_var_old:0.557,explained_var_new:0.694
# batch i:48, episode_len:33
# kl:0.02530,lr_multiplier:1.000,loss:4.301611423492432,entropy:4.088169574737549,explained_var_old:0.588,explained_var_new:0.760
# batch i:49, episode_len:22
# kl:0.03048,lr_multiplier:1.000,loss:4.404550075531006,entropy:4.013597011566162,explained_var_old:0.440,explained_var_new:0.648
# batch i:50, episode_len:23
# kl:0.02930,lr_multiplier:1.000,loss:4.387095928192139,entropy:4.088799476623535,explained_var_old:0.503,explained_var_new:0.661
# current self-play batch: 50
# num_playouts:1000, win: 0, lose: 10, tie:0
# batch i:51, episode_len:22
# kl:0.02370,lr_multiplier:1.000,loss:4.354738235473633,entropy:4.0280961990356445,explained_var_old:0.524,explained_var_new:0.680
# batch i:52, episode_len:24
# kl:0.02734,lr_multiplier:1.000,loss:4.4140496253967285,entropy:4.040489196777344,explained_var_old:0.410,explained_var_new:0.614
# batch i:53, episode_len:16
# kl:0.02434,lr_multiplier:1.000,loss:4.428928852081299,entropy:4.124105453491211,explained_var_old:0.504,explained_var_new:0.649
# batch i:54, episode_len:17
# kl:0.05946,lr_multiplier:0.667,loss:4.335452079772949,entropy:3.894974708557129,explained_var_old:0.477,explained_var_new:0.640
# batch i:55, episode_len:31
# kl:0.05629,lr_multiplier:0.444,loss:4.418537139892578,entropy:4.108495712280273,explained_var_old:0.466,explained_var_new:0.618
# batch i:56, episode_len:16
# kl:0.02197,lr_multiplier:0.444,loss:4.412514686584473,entropy:4.03460693359375,explained_var_old:0.513,explained_var_new:0.616
# batch i:57, episode_len:32
# kl:0.00692,lr_multiplier:0.667,loss:4.447037220001221,entropy:3.9061360359191895,explained_var_old:0.429,explained_var_new:0.536
# batch i:58, episode_len:24
# kl:0.01597,lr_multiplier:0.667,loss:4.394837379455566,entropy:4.008960723876953,explained_var_old:0.472,explained_var_new:0.564
# batch i:59, episode_len:19
# kl:0.01205,lr_multiplier:0.667,loss:4.392477035522461,entropy:3.9561281204223633,explained_var_old:0.409,explained_var_new:0.575
# batch i:60, episode_len:28
# kl:0.01342,lr_multiplier:0.667,loss:4.372921466827393,entropy:3.9573562145233154,explained_var_old:0.452,explained_var_new:0.597
# batch i:61, episode_len:30
# kl:0.02918,lr_multiplier:0.667,loss:4.2667694091796875,entropy:3.8666110038757324,explained_var_old:0.467,explained_var_new:0.615
# batch i:62, episode_len:18
# kl:0.01651,lr_multiplier:0.667,loss:4.373363494873047,entropy:3.919694423675537,explained_var_old:0.386,explained_var_new:0.539
# batch i:63, episode_len:32
# kl:0.01512,lr_multiplier:0.667,loss:4.3711042404174805,entropy:3.917658805847168,explained_var_old:0.408,explained_var_new:0.542
# batch i:64, episode_len:20
# kl:0.01869,lr_multiplier:0.667,loss:4.235790252685547,entropy:3.8170220851898193,explained_var_old:0.469,explained_var_new:0.600
# batch i:65, episode_len:11
# kl:0.01943,lr_multiplier:0.667,loss:4.323054790496826,entropy:3.960557460784912,explained_var_old:0.467,explained_var_new:0.608
# batch i:66, episode_len:27
# kl:0.01278,lr_multiplier:0.667,loss:4.390483379364014,entropy:3.9171271324157715,explained_var_old:0.382,explained_var_new:0.517
# batch i:67, episode_len:17
# kl:0.01646,lr_multiplier:0.667,loss:4.343040943145752,entropy:3.8929271697998047,explained_var_old:0.423,explained_var_new:0.573
# batch i:68, episode_len:26
# kl:0.02085,lr_multiplier:0.667,loss:4.342557907104492,entropy:3.9175944328308105,explained_var_old:0.408,explained_var_new:0.558
# batch i:69, episode_len:24
# kl:0.02951,lr_multiplier:0.667,loss:4.309002876281738,entropy:3.8831708431243896,explained_var_old:0.450,explained_var_new:0.547
# batch i:70, episode_len:22
# kl:0.03101,lr_multiplier:0.667,loss:4.2502760887146,entropy:3.8125011920928955,explained_var_old:0.470,explained_var_new:0.600
# batch i:71, episode_len:22
# kl:0.02379,lr_multiplier:0.667,loss:4.254241943359375,entropy:3.8993372917175293,explained_var_old:0.486,explained_var_new:0.633
# batch i:72, episode_len:13
# kl:0.01369,lr_multiplier:0.667,loss:4.238428592681885,entropy:3.856905460357666,explained_var_old:0.497,explained_var_new:0.621
# batch i:73, episode_len:19
# kl:0.01808,lr_multiplier:0.667,loss:4.306915760040283,entropy:3.8658032417297363,explained_var_old:0.470,explained_var_new:0.591
# batch i:74, episode_len:28
# kl:0.01962,lr_multiplier:0.667,loss:4.21600341796875,entropy:3.8859236240386963,explained_var_old:0.538,explained_var_new:0.655
# batch i:75, episode_len:30
# kl:0.02034,lr_multiplier:0.667,loss:4.180812835693359,entropy:3.811917304992676,explained_var_old:0.475,explained_var_new:0.629
# batch i:76, episode_len:19
# kl:0.01815,lr_multiplier:0.667,loss:4.324857711791992,entropy:3.851332426071167,explained_var_old:0.380,explained_var_new:0.527
# batch i:77, episode_len:19
# kl:0.01268,lr_multiplier:0.667,loss:4.268117904663086,entropy:3.8079419136047363,explained_var_old:0.429,explained_var_new:0.570
# batch i:78, episode_len:19
# kl:0.02211,lr_multiplier:0.667,loss:4.271296977996826,entropy:3.831217050552368,explained_var_old:0.419,explained_var_new:0.545
# batch i:79, episode_len:19
# kl:0.02049,lr_multiplier:0.667,loss:4.276432991027832,entropy:3.7895913124084473,explained_var_old:0.410,explained_var_new:0.537
# batch i:80, episode_len:17
# kl:0.01897,lr_multiplier:0.667,loss:4.316730976104736,entropy:3.9202356338500977,explained_var_old:0.450,explained_var_new:0.596
# batch i:81, episode_len:31
# kl:0.01980,lr_multiplier:0.667,loss:4.387302398681641,entropy:3.8383665084838867,explained_var_old:0.321,explained_var_new:0.488
# batch i:82, episode_len:20
# kl:0.01796,lr_multiplier:0.667,loss:4.280658721923828,entropy:3.814188003540039,explained_var_old:0.374,explained_var_new:0.499
# batch i:83, episode_len:22
# kl:0.01431,lr_multiplier:0.667,loss:4.265933990478516,entropy:3.810018539428711,explained_var_old:0.376,explained_var_new:0.545
# batch i:84, episode_len:19
# kl:0.01780,lr_multiplier:0.667,loss:4.213690757751465,entropy:3.760986328125,explained_var_old:0.437,explained_var_new:0.557
# batch i:85, episode_len:17
# kl:0.02735,lr_multiplier:0.667,loss:4.276403427124023,entropy:3.843334197998047,explained_var_old:0.397,explained_var_new:0.557
# batch i:86, episode_len:12
# kl:0.02370,lr_multiplier:0.667,loss:4.239473819732666,entropy:3.801546573638916,explained_var_old:0.442,explained_var_new:0.558
# batch i:87, episode_len:11
# kl:0.01824,lr_multiplier:0.667,loss:4.16245698928833,entropy:3.768057346343994,explained_var_old:0.480,explained_var_new:0.626
# batch i:88, episode_len:11
# kl:0.01667,lr_multiplier:0.667,loss:4.297015190124512,entropy:3.8278982639312744,explained_var_old:0.352,explained_var_new:0.518
# batch i:89, episode_len:22
# kl:0.01401,lr_multiplier:0.667,loss:4.188536167144775,entropy:3.7737112045288086,explained_var_old:0.440,explained_var_new:0.602
# batch i:90, episode_len:22
# kl:0.02205,lr_multiplier:0.667,loss:4.221840858459473,entropy:3.81197190284729,explained_var_old:0.447,explained_var_new:0.576
# batch i:91, episode_len:18
# kl:0.01893,lr_multiplier:0.667,loss:4.1976213455200195,entropy:3.803748369216919,explained_var_old:0.444,explained_var_new:0.585
# batch i:92, episode_len:20
# kl:0.01607,lr_multiplier:0.667,loss:4.2040934562683105,entropy:3.767214775085449,explained_var_old:0.419,explained_var_new:0.605
# batch i:93, episode_len:20
# kl:0.01824,lr_multiplier:0.667,loss:4.156570911407471,entropy:3.747865676879883,explained_var_old:0.473,explained_var_new:0.606
# batch i:94, episode_len:21
# kl:0.01706,lr_multiplier:0.667,loss:4.214101791381836,entropy:3.8259449005126953,explained_var_old:0.394,explained_var_new:0.556
# batch i:95, episode_len:25
# kl:0.01785,lr_multiplier:0.667,loss:4.17011833190918,entropy:3.753675937652588,explained_var_old:0.451,explained_var_new:0.594
# batch i:96, episode_len:20
# kl:0.01661,lr_multiplier:0.667,loss:4.161552906036377,entropy:3.7396082878112793,explained_var_old:0.484,explained_var_new:0.607
# batch i:97, episode_len:11
# kl:0.01684,lr_multiplier:0.667,loss:4.217038154602051,entropy:3.7573251724243164,explained_var_old:0.446,explained_var_new:0.572
# batch i:98, episode_len:21
# kl:0.01968,lr_multiplier:0.667,loss:4.20390510559082,entropy:3.7315831184387207,explained_var_old:0.350,explained_var_new:0.525
# batch i:99, episode_len:10
# kl:0.02264,lr_multiplier:0.667,loss:4.211929798126221,entropy:3.720848798751831,explained_var_old:0.367,explained_var_new:0.506
# batch i:100, episode_len:13
# kl:0.01500,lr_multiplier:0.667,loss:4.222634315490723,entropy:3.6857049465179443,explained_var_old:0.286,explained_var_new:0.468
# current self-play batch: 100
# num_playouts:1000, win: 0, lose: 10, tie:0
# batch i:101, episode_len:29
# kl:0.02604,lr_multiplier:0.667,loss:4.184386730194092,entropy:3.7917466163635254,explained_var_old:0.468,explained_var_new:0.587
# batch i:102, episode_len:24
# kl:0.02534,lr_multiplier:0.667,loss:4.182985305786133,entropy:3.7419209480285645,explained_var_old:0.439,explained_var_new:0.575
# batch i:103, episode_len:16
# kl:0.02256,lr_multiplier:0.667,loss:4.135053634643555,entropy:3.6602816581726074,explained_var_old:0.384,explained_var_new:0.540
# batch i:104, episode_len:17
# kl:0.02369,lr_multiplier:0.667,loss:4.173477649688721,entropy:3.7870421409606934,explained_var_old:0.415,explained_var_new:0.562
# batch i:105, episode_len:29
# kl:0.02484,lr_multiplier:0.667,loss:4.094635486602783,entropy:3.677293300628662,explained_var_old:0.469,explained_var_new:0.643
# batch i:106, episode_len:19
# kl:0.02735,lr_multiplier:0.667,loss:4.1622419357299805,entropy:3.7434065341949463,explained_var_old:0.394,explained_var_new:0.568
# batch i:107, episode_len:14
# kl:0.01991,lr_multiplier:0.667,loss:4.174587249755859,entropy:3.6796982288360596,explained_var_old:0.384,explained_var_new:0.550
# batch i:108, episode_len:20
# kl:0.02499,lr_multiplier:0.667,loss:4.063944339752197,entropy:3.6500799655914307,explained_var_old:0.427,explained_var_new:0.577
# batch i:109, episode_len:18
# kl:0.02008,lr_multiplier:0.667,loss:4.155096054077148,entropy:3.7297632694244385,explained_var_old:0.405,explained_var_new:0.550
# batch i:110, episode_len:10
# kl:0.02008,lr_multiplier:0.667,loss:4.160539627075195,entropy:3.703486204147339,explained_var_old:0.410,explained_var_new:0.565
# batch i:111, episode_len:17
# kl:0.02401,lr_multiplier:0.667,loss:4.122783660888672,entropy:3.6130380630493164,explained_var_old:0.387,explained_var_new:0.553
# batch i:112, episode_len:12
# kl:0.01983,lr_multiplier:0.667,loss:4.181403160095215,entropy:3.7776408195495605,explained_var_old:0.378,explained_var_new:0.566
# batch i:113, episode_len:16
# kl:0.02437,lr_multiplier:0.667,loss:4.084613800048828,entropy:3.594238758087158,explained_var_old:0.416,explained_var_new:0.556
# batch i:114, episode_len:26
# kl:0.02432,lr_multiplier:0.667,loss:4.101143836975098,entropy:3.648712635040283,explained_var_old:0.398,explained_var_new:0.535
# batch i:115, episode_len:17
# kl:0.02292,lr_multiplier:0.667,loss:4.0547990798950195,entropy:3.6052942276000977,explained_var_old:0.355,explained_var_new:0.529
# batch i:116, episode_len:18
# kl:0.02329,lr_multiplier:0.667,loss:4.0750651359558105,entropy:3.591249942779541,explained_var_old:0.376,explained_var_new:0.520
# batch i:117, episode_len:12
# kl:0.02302,lr_multiplier:0.667,loss:4.1411662101745605,entropy:3.66829776763916,explained_var_old:0.430,explained_var_new:0.544
# batch i:118, episode_len:27
# kl:0.01917,lr_multiplier:0.667,loss:4.083774089813232,entropy:3.599621295928955,explained_var_old:0.389,explained_var_new:0.537
# batch i:119, episode_len:18
# kl:0.02162,lr_multiplier:0.667,loss:4.027195930480957,entropy:3.6183009147644043,explained_var_old:0.478,explained_var_new:0.616
# batch i:120, episode_len:12
# kl:0.01857,lr_multiplier:0.667,loss:4.140460014343262,entropy:3.644284963607788,explained_var_old:0.303,explained_var_new:0.492
# batch i:121, episode_len:23
# kl:0.02336,lr_multiplier:0.667,loss:4.064215660095215,entropy:3.5771286487579346,explained_var_old:0.365,explained_var_new:0.528
# batch i:122, episode_len:21
# kl:0.02389,lr_multiplier:0.667,loss:4.091200351715088,entropy:3.630748748779297,explained_var_old:0.379,explained_var_new:0.516
# batch i:123, episode_len:19
# kl:0.01947,lr_multiplier:0.667,loss:4.162769317626953,entropy:3.5923287868499756,explained_var_old:0.304,explained_var_new:0.458
# batch i:124, episode_len:15
# kl:0.02020,lr_multiplier:0.667,loss:4.051111698150635,entropy:3.5956342220306396,explained_var_old:0.376,explained_var_new:0.526
# batch i:125, episode_len:13
# kl:0.02862,lr_multiplier:0.667,loss:4.032851219177246,entropy:3.535330295562744,explained_var_old:0.359,explained_var_new:0.538
# batch i:126, episode_len:15
# kl:0.02539,lr_multiplier:0.667,loss:4.078394889831543,entropy:3.5488643646240234,explained_var_old:0.313,explained_var_new:0.448
# batch i:127, episode_len:25
# kl:0.02286,lr_multiplier:0.667,loss:4.018718719482422,entropy:3.543200969696045,explained_var_old:0.404,explained_var_new:0.576
# batch i:128, episode_len:16
# kl:0.02325,lr_multiplier:0.667,loss:4.09924840927124,entropy:3.5346620082855225,explained_var_old:0.251,explained_var_new:0.431
# batch i:129, episode_len:22
# kl:0.02160,lr_multiplier:0.667,loss:4.135778903961182,entropy:3.6383628845214844,explained_var_old:0.303,explained_var_new:0.466
# batch i:130, episode_len:22
# kl:0.02635,lr_multiplier:0.667,loss:4.036287784576416,entropy:3.5035572052001953,explained_var_old:0.379,explained_var_new:0.504
# batch i:131, episode_len:11
# kl:0.03312,lr_multiplier:0.667,loss:4.064199924468994,entropy:3.599766492843628,explained_var_old:0.356,explained_var_new:0.515
# batch i:132, episode_len:14
# kl:0.02784,lr_multiplier:0.667,loss:4.022974491119385,entropy:3.476304769515991,explained_var_old:0.341,explained_var_new:0.496
# batch i:133, episode_len:15
# kl:0.04135,lr_multiplier:0.444,loss:4.046695232391357,entropy:3.5990145206451416,explained_var_old:0.399,explained_var_new:0.539
# batch i:134, episode_len:16
# kl:0.01087,lr_multiplier:0.444,loss:4.046914100646973,entropy:3.573530673980713,explained_var_old:0.431,explained_var_new:0.531
# batch i:135, episode_len:8
# kl:0.01431,lr_multiplier:0.444,loss:4.0672993659973145,entropy:3.568337917327881,explained_var_old:0.371,explained_var_new:0.479
# batch i:136, episode_len:22
# kl:0.01318,lr_multiplier:0.444,loss:3.987966537475586,entropy:3.506005048751831,explained_var_old:0.420,explained_var_new:0.540
# batch i:137, episode_len:14
# kl:0.01980,lr_multiplier:0.444,loss:3.989323616027832,entropy:3.484156608581543,explained_var_old:0.405,explained_var_new:0.522
# batch i:138, episode_len:30
# kl:0.02100,lr_multiplier:0.444,loss:4.071572303771973,entropy:3.5675737857818604,explained_var_old:0.360,explained_var_new:0.501
# batch i:139, episode_len:14
# kl:0.02212,lr_multiplier:0.444,loss:4.01244592666626,entropy:3.5187363624572754,explained_var_old:0.354,explained_var_new:0.507
# batch i:140, episode_len:14
# kl:0.01273,lr_multiplier:0.444,loss:4.131983280181885,entropy:3.54058837890625,explained_var_old:0.316,explained_var_new:0.434
# batch i:141, episode_len:13
# kl:0.01144,lr_multiplier:0.444,loss:4.049731731414795,entropy:3.5950961112976074,explained_var_old:0.392,explained_var_new:0.499
# batch i:142, episode_len:21
# kl:0.01575,lr_multiplier:0.444,loss:4.06891393661499,entropy:3.5189337730407715,explained_var_old:0.359,explained_var_new:0.456
# batch i:143, episode_len:7
# kl:0.01784,lr_multiplier:0.444,loss:3.9828474521636963,entropy:3.4615442752838135,explained_var_old:0.391,explained_var_new:0.497
# batch i:144, episode_len:10
# kl:0.01659,lr_multiplier:0.444,loss:4.023748874664307,entropy:3.48972749710083,explained_var_old:0.400,explained_var_new:0.492
# batch i:145, episode_len:27
# kl:0.01193,lr_multiplier:0.444,loss:4.021233558654785,entropy:3.561357021331787,explained_var_old:0.375,explained_var_new:0.502
# batch i:146, episode_len:14
# kl:0.01529,lr_multiplier:0.444,loss:4.087617874145508,entropy:3.504732131958008,explained_var_old:0.336,explained_var_new:0.440
# batch i:147, episode_len:11
# kl:0.02016,lr_multiplier:0.444,loss:4.153989791870117,entropy:3.538957118988037,explained_var_old:0.275,explained_var_new:0.393
# batch i:148, episode_len:9
# kl:0.01573,lr_multiplier:0.444,loss:4.099574565887451,entropy:3.5573015213012695,explained_var_old:0.304,explained_var_new:0.452
# batch i:149, episode_len:15
# kl:0.01438,lr_multiplier:0.444,loss:4.052162170410156,entropy:3.530269145965576,explained_var_old:0.388,explained_var_new:0.479
# batch i:150, episode_len:7
# kl:0.01703,lr_multiplier:0.444,loss:4.073118686676025,entropy:3.536484479904175,explained_var_old:0.351,explained_var_new:0.462
# current self-play batch: 150
# num_playouts:1000, win: 6, lose: 4, tie:0
# 发现新的最优策略，进行策略更新
# batch i:151, episode_len:11
# kl:0.01322,lr_multiplier:0.444,loss:4.028457164764404,entropy:3.4664688110351562,explained_var_old:0.322,explained_var_new:0.429
# batch i:152, episode_len:14
# kl:0.01872,lr_multiplier:0.444,loss:3.9926445484161377,entropy:3.4338765144348145,explained_var_old:0.365,explained_var_new:0.478
# batch i:153, episode_len:27
# kl:0.02598,lr_multiplier:0.444,loss:4.066829681396484,entropy:3.5124828815460205,explained_var_old:0.377,explained_var_new:0.463
# batch i:154, episode_len:10
# kl:0.01582,lr_multiplier:0.444,loss:4.045713901519775,entropy:3.5632548332214355,explained_var_old:0.394,explained_var_new:0.504
# batch i:155, episode_len:18
# kl:0.02533,lr_multiplier:0.444,loss:4.0008745193481445,entropy:3.469689130783081,explained_var_old:0.383,explained_var_new:0.513
# batch i:156, episode_len:19
# kl:0.01549,lr_multiplier:0.444,loss:4.0298662185668945,entropy:3.520369291305542,explained_var_old:0.361,explained_var_new:0.486
# batch i:157, episode_len:16
# kl:0.01276,lr_multiplier:0.444,loss:3.964008092880249,entropy:3.5136499404907227,explained_var_old:0.408,explained_var_new:0.502
# batch i:158, episode_len:12
# kl:0.02033,lr_multiplier:0.444,loss:3.98185658454895,entropy:3.4633116722106934,explained_var_old:0.392,explained_var_new:0.531
# batch i:159, episode_len:20
# kl:0.02553,lr_multiplier:0.444,loss:3.9087235927581787,entropy:3.4419825077056885,explained_var_old:0.414,explained_var_new:0.550
# batch i:160, episode_len:9
# kl:0.01515,lr_multiplier:0.444,loss:3.952878475189209,entropy:3.5105366706848145,explained_var_old:0.394,explained_var_new:0.534
# batch i:161, episode_len:11
# kl:0.01406,lr_multiplier:0.444,loss:3.99131441116333,entropy:3.476443290710449,explained_var_old:0.382,explained_var_new:0.474
# batch i:162, episode_len:7
# kl:0.01280,lr_multiplier:0.444,loss:3.953070640563965,entropy:3.4233450889587402,explained_var_old:0.406,explained_var_new:0.514
# batch i:163, episode_len:12
# kl:0.01950,lr_multiplier:0.444,loss:4.0206451416015625,entropy:3.5181851387023926,explained_var_old:0.406,explained_var_new:0.500
# batch i:164, episode_len:10
# kl:0.01461,lr_multiplier:0.444,loss:3.9863009452819824,entropy:3.5055575370788574,explained_var_old:0.350,explained_var_new:0.483
# batch i:165, episode_len:15
# kl:0.01373,lr_multiplier:0.444,loss:3.9894962310791016,entropy:3.42781925201416,explained_var_old:0.379,explained_var_new:0.511
# batch i:166, episode_len:23
# kl:0.01631,lr_multiplier:0.444,loss:3.901674270629883,entropy:3.473358392715454,explained_var_old:0.441,explained_var_new:0.549
# batch i:167, episode_len:19
# kl:0.01162,lr_multiplier:0.444,loss:3.8423402309417725,entropy:3.4536662101745605,explained_var_old:0.373,explained_var_new:0.537
# batch i:168, episode_len:9
# kl:0.01838,lr_multiplier:0.444,loss:3.9422507286071777,entropy:3.442873001098633,explained_var_old:0.439,explained_var_new:0.546
# batch i:169, episode_len:25
# kl:0.01233,lr_multiplier:0.444,loss:3.944185972213745,entropy:3.4338319301605225,explained_var_old:0.399,explained_var_new:0.535
# batch i:170, episode_len:12
# kl:0.01407,lr_multiplier:0.444,loss:3.8878912925720215,entropy:3.4091320037841797,explained_var_old:0.401,explained_var_new:0.555
# batch i:171, episode_len:13
# kl:0.01333,lr_multiplier:0.444,loss:3.8757026195526123,entropy:3.417938709259033,explained_var_old:0.445,explained_var_new:0.569
# batch i:172, episode_len:9
# kl:0.01428,lr_multiplier:0.444,loss:3.9301209449768066,entropy:3.5093297958374023,explained_var_old:0.453,explained_var_new:0.559
# batch i:173, episode_len:14
# kl:0.01776,lr_multiplier:0.444,loss:3.883802890777588,entropy:3.4835214614868164,explained_var_old:0.489,explained_var_new:0.586
# batch i:174, episode_len:20
# kl:0.01657,lr_multiplier:0.444,loss:3.7649967670440674,entropy:3.3424997329711914,explained_var_old:0.504,explained_var_new:0.612
# batch i:175, episode_len:19
# kl:0.02397,lr_multiplier:0.444,loss:3.8203117847442627,entropy:3.3974204063415527,explained_var_old:0.467,explained_var_new:0.590
# batch i:176, episode_len:8
# kl:0.02055,lr_multiplier:0.444,loss:3.915205240249634,entropy:3.47902512550354,explained_var_old:0.436,explained_var_new:0.582
# batch i:177, episode_len:7
# kl:0.02012,lr_multiplier:0.444,loss:3.76296067237854,entropy:3.3447036743164062,explained_var_old:0.508,explained_var_new:0.607
# batch i:178, episode_len:7
# kl:0.01109,lr_multiplier:0.444,loss:3.8058555126190186,entropy:3.405329704284668,explained_var_old:0.464,explained_var_new:0.616
# batch i:179, episode_len:10
# kl:0.01253,lr_multiplier:0.444,loss:3.744309186935425,entropy:3.3782267570495605,explained_var_old:0.529,explained_var_new:0.645
# batch i:180, episode_len:11
# kl:0.02260,lr_multiplier:0.444,loss:3.807114839553833,entropy:3.3887510299682617,explained_var_old:0.487,explained_var_new:0.607
# batch i:181, episode_len:12
# kl:0.03320,lr_multiplier:0.444,loss:3.657719135284424,entropy:3.2962288856506348,explained_var_old:0.527,explained_var_new:0.633
# batch i:182, episode_len:12
# kl:0.05563,lr_multiplier:0.296,loss:3.8062615394592285,entropy:3.433335781097412,explained_var_old:0.483,explained_var_new:0.564
# batch i:183, episode_len:9
# kl:0.03502,lr_multiplier:0.296,loss:3.782430410385132,entropy:3.388052225112915,explained_var_old:0.498,explained_var_new:0.592
# batch i:184, episode_len:13
# kl:0.01375,lr_multiplier:0.296,loss:3.7673957347869873,entropy:3.283539295196533,explained_var_old:0.461,explained_var_new:0.556
# batch i:185, episode_len:11
# kl:0.01883,lr_multiplier:0.296,loss:3.811046600341797,entropy:3.3911869525909424,explained_var_old:0.507,explained_var_new:0.598
# batch i:186, episode_len:16
# kl:0.03038,lr_multiplier:0.296,loss:3.710983991622925,entropy:3.337010622024536,explained_var_old:0.533,explained_var_new:0.616
# batch i:187, episode_len:8
# kl:0.02195,lr_multiplier:0.296,loss:3.6876187324523926,entropy:3.3228635787963867,explained_var_old:0.554,explained_var_new:0.617
# batch i:188, episode_len:20
# kl:0.00820,lr_multiplier:0.444,loss:3.757711887359619,entropy:3.3504300117492676,explained_var_old:0.498,explained_var_new:0.591
# batch i:189, episode_len:13
# kl:0.01381,lr_multiplier:0.444,loss:3.6847853660583496,entropy:3.2054314613342285,explained_var_old:0.480,explained_var_new:0.569
# batch i:190, episode_len:13
# kl:0.01137,lr_multiplier:0.444,loss:3.7289464473724365,entropy:3.319296360015869,explained_var_old:0.464,explained_var_new:0.578
# batch i:191, episode_len:12
# kl:0.01514,lr_multiplier:0.444,loss:3.7726197242736816,entropy:3.3773837089538574,explained_var_old:0.497,explained_var_new:0.593
# batch i:192, episode_len:11
# kl:0.00962,lr_multiplier:0.667,loss:3.673603057861328,entropy:3.3239026069641113,explained_var_old:0.502,explained_var_new:0.622
# batch i:193, episode_len:8
# kl:0.02577,lr_multiplier:0.667,loss:3.7092177867889404,entropy:3.231231689453125,explained_var_old:0.487,explained_var_new:0.618
# batch i:194, episode_len:7
# kl:0.02522,lr_multiplier:0.667,loss:3.7021024227142334,entropy:3.3209495544433594,explained_var_old:0.452,explained_var_new:0.591
# batch i:195, episode_len:11
# kl:0.01907,lr_multiplier:0.667,loss:3.6983587741851807,entropy:3.418379545211792,explained_var_old:0.579,explained_var_new:0.693
# batch i:196, episode_len:8
# kl:0.02186,lr_multiplier:0.667,loss:3.606109380722046,entropy:3.270814895629883,explained_var_old:0.531,explained_var_new:0.680
# batch i:197, episode_len:15
# kl:0.02774,lr_multiplier:0.667,loss:3.7480432987213135,entropy:3.396742582321167,explained_var_old:0.457,explained_var_new:0.611
# batch i:198, episode_len:9
# kl:0.02521,lr_multiplier:0.667,loss:3.624696731567383,entropy:3.1855344772338867,explained_var_old:0.475,explained_var_new:0.609
# batch i:199, episode_len:15
# kl:0.03552,lr_multiplier:0.667,loss:3.651092290878296,entropy:3.340815782546997,explained_var_old:0.497,explained_var_new:0.638
# batch i:200, episode_len:9
# kl:0.02157,lr_multiplier:0.667,loss:3.7711338996887207,entropy:3.3893074989318848,explained_var_old:0.436,explained_var_new:0.595
# current self-play batch: 200
# num_playouts:1000, win: 3, lose: 7, tie:0
# batch i:201, episode_len:11
# kl:0.02692,lr_multiplier:0.667,loss:3.5569958686828613,entropy:3.148866891860962,explained_var_old:0.469,explained_var_new:0.611
# batch i:202, episode_len:17
# kl:0.03208,lr_multiplier:0.667,loss:3.7039690017700195,entropy:3.344773054122925,explained_var_old:0.495,explained_var_new:0.616
# batch i:203, episode_len:10
# kl:0.02268,lr_multiplier:0.667,loss:3.664799928665161,entropy:3.296565532684326,explained_var_old:0.553,explained_var_new:0.681
# batch i:204, episode_len:9
# kl:0.02659,lr_multiplier:0.667,loss:3.5196728706359863,entropy:3.1677017211914062,explained_var_old:0.546,explained_var_new:0.668
# batch i:205, episode_len:8
# kl:0.02486,lr_multiplier:0.667,loss:3.517798900604248,entropy:3.155534029006958,explained_var_old:0.514,explained_var_new:0.652
# batch i:206, episode_len:18
# kl:0.02340,lr_multiplier:0.667,loss:3.5482852458953857,entropy:3.1495418548583984,explained_var_old:0.493,explained_var_new:0.652
# batch i:207, episode_len:16
# kl:0.03528,lr_multiplier:0.667,loss:3.4739370346069336,entropy:3.258845090866089,explained_var_old:0.523,explained_var_new:0.692
# batch i:208, episode_len:12
# kl:0.04187,lr_multiplier:0.444,loss:3.638864517211914,entropy:3.199894905090332,explained_var_old:0.497,explained_var_new:0.647
# batch i:209, episode_len:9
# kl:0.01742,lr_multiplier:0.444,loss:3.539875030517578,entropy:3.2065298557281494,explained_var_old:0.460,explained_var_new:0.642
# batch i:210, episode_len:10
# kl:0.01735,lr_multiplier:0.444,loss:3.589473009109497,entropy:3.2447264194488525,explained_var_old:0.524,explained_var_new:0.623
# batch i:211, episode_len:14
# kl:0.01519,lr_multiplier:0.444,loss:3.543488025665283,entropy:3.1772053241729736,explained_var_old:0.548,explained_var_new:0.647
# batch i:212, episode_len:11
# kl:0.01618,lr_multiplier:0.444,loss:3.6493539810180664,entropy:3.2830071449279785,explained_var_old:0.497,explained_var_new:0.619
# batch i:213, episode_len:14
# kl:0.00962,lr_multiplier:0.667,loss:3.6389758586883545,entropy:3.272144079208374,explained_var_old:0.528,explained_var_new:0.629
# batch i:214, episode_len:14
# kl:0.02849,lr_multiplier:0.667,loss:3.53728985786438,entropy:3.1390113830566406,explained_var_old:0.539,explained_var_new:0.645
# batch i:215, episode_len:12
# kl:0.03279,lr_multiplier:0.667,loss:3.607557773590088,entropy:3.16300892829895,explained_var_old:0.403,explained_var_new:0.555
# batch i:216, episode_len:18
# kl:0.02556,lr_multiplier:0.667,loss:3.620556592941284,entropy:3.1527655124664307,explained_var_old:0.384,explained_var_new:0.562
# batch i:217, episode_len:8
# kl:0.02186,lr_multiplier:0.667,loss:3.670778512954712,entropy:3.286684513092041,explained_var_old:0.463,explained_var_new:0.601
# batch i:218, episode_len:15
# kl:0.02570,lr_multiplier:0.667,loss:3.5621814727783203,entropy:3.0939269065856934,explained_var_old:0.441,explained_var_new:0.541
# batch i:219, episode_len:10
# kl:0.02315,lr_multiplier:0.667,loss:3.549643039703369,entropy:3.13169527053833,explained_var_old:0.431,explained_var_new:0.585
# batch i:220, episode_len:12
# kl:0.03079,lr_multiplier:0.667,loss:3.491689682006836,entropy:3.1392078399658203,explained_var_old:0.454,explained_var_new:0.583
# batch i:221, episode_len:8
# kl:0.02806,lr_multiplier:0.667,loss:3.6711654663085938,entropy:3.183932304382324,explained_var_old:0.350,explained_var_new:0.500
# batch i:222, episode_len:18
# kl:0.01659,lr_multiplier:0.667,loss:3.5517654418945312,entropy:3.0756304264068604,explained_var_old:0.430,explained_var_new:0.559
# batch i:223, episode_len:12
# kl:0.02195,lr_multiplier:0.667,loss:3.541931629180908,entropy:3.081289529800415,explained_var_old:0.419,explained_var_new:0.552
# batch i:224, episode_len:9
# kl:0.03011,lr_multiplier:0.667,loss:3.534593105316162,entropy:3.0870847702026367,explained_var_old:0.399,explained_var_new:0.546
# batch i:225, episode_len:8
# kl:0.01694,lr_multiplier:0.667,loss:3.5463900566101074,entropy:3.0916671752929688,explained_var_old:0.388,explained_var_new:0.564
# batch i:226, episode_len:9
# kl:0.03335,lr_multiplier:0.667,loss:3.5732059478759766,entropy:3.0875391960144043,explained_var_old:0.414,explained_var_new:0.555
# batch i:227, episode_len:11
# kl:0.02944,lr_multiplier:0.667,loss:3.577723264694214,entropy:3.1365809440612793,explained_var_old:0.436,explained_var_new:0.546
# batch i:228, episode_len:13
# kl:0.02478,lr_multiplier:0.667,loss:3.6223044395446777,entropy:3.1228907108306885,explained_var_old:0.385,explained_var_new:0.507
# batch i:229, episode_len:9
# kl:0.02824,lr_multiplier:0.667,loss:3.6168789863586426,entropy:3.125182867050171,explained_var_old:0.349,explained_var_new:0.480
# batch i:230, episode_len:16
# kl:0.03137,lr_multiplier:0.667,loss:3.557645559310913,entropy:3.0283427238464355,explained_var_old:0.344,explained_var_new:0.507
# batch i:231, episode_len:8
# kl:0.02883,lr_multiplier:0.667,loss:3.578193187713623,entropy:3.092725992202759,explained_var_old:0.424,explained_var_new:0.536
# batch i:232, episode_len:9
# kl:0.02047,lr_multiplier:0.667,loss:3.665738582611084,entropy:3.207822561264038,explained_var_old:0.398,explained_var_new:0.520
# batch i:233, episode_len:7
# kl:0.05331,lr_multiplier:0.444,loss:3.53045654296875,entropy:3.0504956245422363,explained_var_old:0.416,explained_var_new:0.547
# batch i:234, episode_len:10
# kl:0.03963,lr_multiplier:0.444,loss:3.5256214141845703,entropy:3.027376651763916,explained_var_old:0.425,explained_var_new:0.540
# batch i:235, episode_len:12
# kl:0.02099,lr_multiplier:0.444,loss:3.523292064666748,entropy:3.0912094116210938,explained_var_old:0.402,explained_var_new:0.540
# batch i:236, episode_len:8
# kl:0.01176,lr_multiplier:0.444,loss:3.4745101928710938,entropy:2.9703474044799805,explained_var_old:0.447,explained_var_new:0.557
# batch i:237, episode_len:14
# kl:0.01195,lr_multiplier:0.444,loss:3.574791669845581,entropy:3.0618982315063477,explained_var_old:0.382,explained_var_new:0.483
# batch i:238, episode_len:9
# kl:0.01480,lr_multiplier:0.444,loss:3.528677463531494,entropy:3.111319065093994,explained_var_old:0.464,explained_var_new:0.540
# batch i:239, episode_len:7
# kl:0.01486,lr_multiplier:0.444,loss:3.575991630554199,entropy:3.047243118286133,explained_var_old:0.358,explained_var_new:0.456
# batch i:240, episode_len:9
# kl:0.01318,lr_multiplier:0.444,loss:3.5047359466552734,entropy:2.9804656505584717,explained_var_old:0.420,explained_var_new:0.505
# batch i:241, episode_len:7
# kl:0.01372,lr_multiplier:0.444,loss:3.452310085296631,entropy:2.926839828491211,explained_var_old:0.406,explained_var_new:0.478
# batch i:242, episode_len:13
# kl:0.01672,lr_multiplier:0.444,loss:3.465488910675049,entropy:2.9622743129730225,explained_var_old:0.403,explained_var_new:0.505
# batch i:243, episode_len:12
# kl:0.01219,lr_multiplier:0.444,loss:3.504318952560425,entropy:3.0538384914398193,explained_var_old:0.403,explained_var_new:0.492
# batch i:244, episode_len:7
# kl:0.01678,lr_multiplier:0.444,loss:3.4507668018341064,entropy:2.923957347869873,explained_var_old:0.409,explained_var_new:0.486
# batch i:245, episode_len:9
# kl:0.01103,lr_multiplier:0.444,loss:3.476166248321533,entropy:2.919633388519287,explained_var_old:0.350,explained_var_new:0.431
# batch i:246, episode_len:15
# kl:0.02287,lr_multiplier:0.444,loss:3.440401792526245,entropy:2.9857258796691895,explained_var_old:0.435,explained_var_new:0.520
# batch i:247, episode_len:7
# kl:0.01156,lr_multiplier:0.444,loss:3.4949300289154053,entropy:2.96856951713562,explained_var_old:0.437,explained_var_new:0.519
# batch i:248, episode_len:15
# kl:0.01055,lr_multiplier:0.444,loss:3.397249460220337,entropy:2.916595458984375,explained_var_old:0.435,explained_var_new:0.526
# batch i:249, episode_len:7
# kl:0.01674,lr_multiplier:0.444,loss:3.4709439277648926,entropy:2.92279052734375,explained_var_old:0.345,explained_var_new:0.437
# batch i:250, episode_len:20
# kl:0.01458,lr_multiplier:0.444,loss:3.481492757797241,entropy:2.9430904388427734,explained_var_old:0.394,explained_var_new:0.496
# current self-play batch: 250
# num_playouts:1000, win: 9, lose: 1, tie:0
# 发现新的最优策略，进行策略更新
# batch i:251, episode_len:7
# kl:0.01546,lr_multiplier:0.444,loss:3.453200340270996,entropy:2.992633581161499,explained_var_old:0.425,explained_var_new:0.503
# batch i:252, episode_len:7
# kl:0.01467,lr_multiplier:0.444,loss:3.4582834243774414,entropy:2.9626195430755615,explained_var_old:0.393,explained_var_new:0.491
# batch i:253, episode_len:9
# kl:0.01573,lr_multiplier:0.444,loss:3.4697184562683105,entropy:2.9277167320251465,explained_var_old:0.421,explained_var_new:0.516
# batch i:254, episode_len:8
# kl:0.00944,lr_multiplier:0.667,loss:3.522081136703491,entropy:3.0131616592407227,explained_var_old:0.386,explained_var_new:0.482
# batch i:255, episode_len:7
# kl:0.02499,lr_multiplier:0.667,loss:3.319448709487915,entropy:2.936326026916504,explained_var_old:0.487,explained_var_new:0.586
# batch i:256, episode_len:9
# kl:0.02476,lr_multiplier:0.667,loss:3.3417630195617676,entropy:2.8664798736572266,explained_var_old:0.428,explained_var_new:0.565
# batch i:257, episode_len:15
# kl:0.02643,lr_multiplier:0.667,loss:3.2464706897735596,entropy:2.8267931938171387,explained_var_old:0.453,explained_var_new:0.585
# batch i:258, episode_len:14
# kl:0.02537,lr_multiplier:0.667,loss:3.462928533554077,entropy:2.948537826538086,explained_var_old:0.393,explained_var_new:0.510
# batch i:259, episode_len:11
# kl:0.03430,lr_multiplier:0.667,loss:3.3839974403381348,entropy:2.958357810974121,explained_var_old:0.382,explained_var_new:0.498
# batch i:260, episode_len:9
# kl:0.02929,lr_multiplier:0.667,loss:3.3365261554718018,entropy:2.852996587753296,explained_var_old:0.414,explained_var_new:0.565
# batch i:261, episode_len:7
# kl:0.03066,lr_multiplier:0.667,loss:3.3813343048095703,entropy:2.8561644554138184,explained_var_old:0.360,explained_var_new:0.507
# batch i:262, episode_len:15
# kl:0.02512,lr_multiplier:0.667,loss:3.381093740463257,entropy:2.8924100399017334,explained_var_old:0.395,explained_var_new:0.519
# batch i:263, episode_len:10
# kl:0.02909,lr_multiplier:0.667,loss:3.314664363861084,entropy:2.834900379180908,explained_var_old:0.435,explained_var_new:0.537
# batch i:264, episode_len:18
# kl:0.03103,lr_multiplier:0.667,loss:3.3703715801239014,entropy:2.983562469482422,explained_var_old:0.419,explained_var_new:0.546
# batch i:265, episode_len:9
# kl:0.04445,lr_multiplier:0.444,loss:3.3496367931365967,entropy:2.781672477722168,explained_var_old:0.378,explained_var_new:0.480
# batch i:266, episode_len:11
# kl:0.03867,lr_multiplier:0.444,loss:3.3295490741729736,entropy:2.785794258117676,explained_var_old:0.368,explained_var_new:0.513
# batch i:267, episode_len:14
# kl:0.02134,lr_multiplier:0.444,loss:3.180002212524414,entropy:2.764129638671875,explained_var_old:0.445,explained_var_new:0.531
# batch i:268, episode_len:11
# kl:0.01686,lr_multiplier:0.444,loss:3.332839250564575,entropy:2.8398475646972656,explained_var_old:0.416,explained_var_new:0.516
# batch i:269, episode_len:9
# kl:0.01641,lr_multiplier:0.444,loss:3.340515613555908,entropy:2.8522489070892334,explained_var_old:0.405,explained_var_new:0.510
# batch i:270, episode_len:11
# kl:0.01555,lr_multiplier:0.444,loss:3.2321085929870605,entropy:2.801945447921753,explained_var_old:0.493,explained_var_new:0.587
# batch i:271, episode_len:7
# kl:0.01400,lr_multiplier:0.444,loss:3.274526357650757,entropy:2.8540613651275635,explained_var_old:0.505,explained_var_new:0.597
# batch i:272, episode_len:7
# kl:0.01144,lr_multiplier:0.444,loss:3.135181427001953,entropy:2.7118799686431885,explained_var_old:0.471,explained_var_new:0.558
# batch i:273, episode_len:9
# kl:0.01323,lr_multiplier:0.444,loss:3.2409284114837646,entropy:2.7981863021850586,explained_var_old:0.471,explained_var_new:0.570
# batch i:274, episode_len:11
# kl:0.01676,lr_multiplier:0.444,loss:3.167320728302002,entropy:2.7383744716644287,explained_var_old:0.503,explained_var_new:0.584
# batch i:275, episode_len:9
# kl:0.00994,lr_multiplier:0.667,loss:3.2200727462768555,entropy:2.695378303527832,explained_var_old:0.413,explained_var_new:0.485
# batch i:276, episode_len:12
# kl:0.02824,lr_multiplier:0.667,loss:3.171307325363159,entropy:2.802734375,explained_var_old:0.449,explained_var_new:0.548
# batch i:277, episode_len:10
# kl:0.02307,lr_multiplier:0.667,loss:3.2034008502960205,entropy:2.680119037628174,explained_var_old:0.405,explained_var_new:0.559
# batch i:278, episode_len:11
# kl:0.03127,lr_multiplier:0.667,loss:3.3368518352508545,entropy:2.81781005859375,explained_var_old:0.332,explained_var_new:0.494
# batch i:279, episode_len:15
# kl:0.02203,lr_multiplier:0.667,loss:3.267277240753174,entropy:2.8715381622314453,explained_var_old:0.404,explained_var_new:0.561
# batch i:280, episode_len:15
# kl:0.02808,lr_multiplier:0.667,loss:3.213406562805176,entropy:2.6675992012023926,explained_var_old:0.388,explained_var_new:0.526
# batch i:281, episode_len:16
# kl:0.03203,lr_multiplier:0.667,loss:3.1347880363464355,entropy:2.732922077178955,explained_var_old:0.439,explained_var_new:0.572
# batch i:282, episode_len:13
# kl:0.02680,lr_multiplier:0.667,loss:3.292865037918091,entropy:2.8154497146606445,explained_var_old:0.394,explained_var_new:0.541
# batch i:283, episode_len:7
# kl:0.02005,lr_multiplier:0.667,loss:3.092721939086914,entropy:2.668907642364502,explained_var_old:0.453,explained_var_new:0.604
# batch i:284, episode_len:9
# kl:0.02319,lr_multiplier:0.667,loss:3.1170172691345215,entropy:2.7514405250549316,explained_var_old:0.468,explained_var_new:0.599
# batch i:285, episode_len:7
# kl:0.02269,lr_multiplier:0.667,loss:3.2245590686798096,entropy:2.7503113746643066,explained_var_old:0.369,explained_var_new:0.536
# batch i:286, episode_len:14
# kl:0.02142,lr_multiplier:0.667,loss:3.194329261779785,entropy:2.6635680198669434,explained_var_old:0.330,explained_var_new:0.480
# batch i:287, episode_len:11
# kl:0.03512,lr_multiplier:0.667,loss:3.038811683654785,entropy:2.6193785667419434,explained_var_old:0.394,explained_var_new:0.552
# batch i:288, episode_len:21
# kl:0.02727,lr_multiplier:0.667,loss:3.225393295288086,entropy:2.709714889526367,explained_var_old:0.371,explained_var_new:0.512
# batch i:289, episode_len:20
# kl:0.03959,lr_multiplier:0.667,loss:3.197627305984497,entropy:2.698197841644287,explained_var_old:0.382,explained_var_new:0.503
# batch i:290, episode_len:8
# kl:0.02273,lr_multiplier:0.667,loss:3.1244137287139893,entropy:2.6272926330566406,explained_var_old:0.378,explained_var_new:0.515
# batch i:291, episode_len:13
# kl:0.02599,lr_multiplier:0.667,loss:3.1387898921966553,entropy:2.6604607105255127,explained_var_old:0.411,explained_var_new:0.542
# batch i:292, episode_len:13
# kl:0.03320,lr_multiplier:0.667,loss:3.052215099334717,entropy:2.583664655685425,explained_var_old:0.409,explained_var_new:0.538
# batch i:293, episode_len:16
# kl:0.02766,lr_multiplier:0.667,loss:3.0047860145568848,entropy:2.5706069469451904,explained_var_old:0.448,explained_var_new:0.578
# batch i:294, episode_len:21
# kl:0.03619,lr_multiplier:0.667,loss:3.0617027282714844,entropy:2.6551756858825684,explained_var_old:0.463,explained_var_new:0.547
# batch i:295, episode_len:12
# kl:0.02942,lr_multiplier:0.667,loss:3.076552629470825,entropy:2.658940315246582,explained_var_old:0.422,explained_var_new:0.536
# batch i:296, episode_len:13
# kl:0.03932,lr_multiplier:0.667,loss:3.1284656524658203,entropy:2.607341766357422,explained_var_old:0.345,explained_var_new:0.486
# batch i:297, episode_len:13
# kl:0.02614,lr_multiplier:0.667,loss:3.147533893585205,entropy:2.6506237983703613,explained_var_old:0.418,explained_var_new:0.546
# batch i:298, episode_len:9
# kl:0.02613,lr_multiplier:0.667,loss:3.134737968444824,entropy:2.69199800491333,explained_var_old:0.412,explained_var_new:0.536
# batch i:299, episode_len:19
# kl:0.02592,lr_multiplier:0.667,loss:3.1269826889038086,entropy:2.6590166091918945,explained_var_old:0.416,explained_var_new:0.540
# batch i:300, episode_len:9
# kl:0.01921,lr_multiplier:0.667,loss:3.0643515586853027,entropy:2.55379581451416,explained_var_old:0.332,explained_var_new:0.504
# current self-play batch: 300
# num_playouts:1000, win: 8, lose: 2, tie:0
# batch i:301, episode_len:8
# kl:0.03354,lr_multiplier:0.667,loss:3.050220012664795,entropy:2.605863571166992,explained_var_old:0.393,explained_var_new:0.532
# batch i:302, episode_len:9
# kl:0.03177,lr_multiplier:0.667,loss:3.0725080966949463,entropy:2.563589572906494,explained_var_old:0.383,explained_var_new:0.515
# batch i:303, episode_len:14
# kl:0.02524,lr_multiplier:0.667,loss:2.99489688873291,entropy:2.5618104934692383,explained_var_old:0.420,explained_var_new:0.560
# batch i:304, episode_len:16
# kl:0.02658,lr_multiplier:0.667,loss:2.9152913093566895,entropy:2.4843785762786865,explained_var_old:0.471,explained_var_new:0.593
# batch i:305, episode_len:8
# ...
# kl:0.01291,lr_multiplier:0.296,loss:2.8616926670074463,entropy:2.3411362171173096,explained_var_old:0.406,explained_var_new:0.479
# current self-play batch: 400
# num_playouts:1000, win: 8, lose: 2, tie:0
# batch i:401, episode_len:7
# kl:0.00803,lr_multiplier:0.444,loss:2.904247760772705,entropy:2.3950743675231934,explained_var_old:0.442,explained_var_new:0.501
# batch i:402, episode_len:12
# kl:0.01516,lr_multiplier:0.444,loss:2.754770278930664,entropy:2.3125803470611572,explained_var_old:0.466,explained_var_new:0.552
# batch i:403, episode_len:7
# kl:0.01872,lr_multiplier:0.444,loss:2.9022481441497803,entropy:2.381132125854492,explained_var_old:0.367,explained_var_new:0.475
# batch i:404, episode_len:8
# kl:0.02271,lr_multiplier:0.444,loss:2.8205699920654297,entropy:2.379564046859741,explained_var_old:0.489,explained_var_new:0.550
# batch i:405, episode_len:7
# kl:0.01820,lr_multiplier:0.444,loss:2.868281364440918,entropy:2.405275821685791,explained_var_old:0.434,explained_var_new:0.532
# batch i:406, episode_len:9
# kl:0.01432,lr_multiplier:0.444,loss:2.7880938053131104,entropy:2.287533760070801,explained_var_old:0.443,explained_var_new:0.517
# batch i:407, episode_len:13
# kl:0.01356,lr_multiplier:0.444,loss:2.7516167163848877,entropy:2.278106212615967,explained_var_old:0.463,explained_var_new:0.545
# batch i:408, episode_len:8
# kl:0.01930,lr_multiplier:0.444,loss:2.8283419609069824,entropy:2.3266005516052246,explained_var_old:0.370,explained_var_new:0.478
# batch i:409, episode_len:14
# kl:0.05010,lr_multiplier:0.296,loss:2.7894623279571533,entropy:2.327017307281494,explained_var_old:0.458,explained_var_new:0.543
# batch i:410, episode_len:12
# kl:0.02412,lr_multiplier:0.296,loss:2.7554550170898438,entropy:2.293408155441284,explained_var_old:0.387,explained_var_new:0.482
# batch i:411, episode_len:12
# kl:0.01289,lr_multiplier:0.296,loss:2.811832904815674,entropy:2.258004903793335,explained_var_old:0.404,explained_var_new:0.473
# batch i:412, episode_len:19
# kl:0.00800,lr_multiplier:0.444,loss:2.98591685295105,entropy:2.3974533081054688,explained_var_old:0.347,explained_var_new:0.430
# batch i:413, episode_len:16
# kl:0.02482,lr_multiplier:0.444,loss:2.894867181777954,entropy:2.3967461585998535,explained_var_old:0.376,explained_var_new:0.479
# batch i:414, episode_len:11
# kl:0.02258,lr_multiplier:0.444,loss:2.8596954345703125,entropy:2.330857753753662,explained_var_old:0.360,explained_var_new:0.467
# batch i:415, episode_len:11
# kl:0.02715,lr_multiplier:0.444,loss:2.7709224224090576,entropy:2.2528328895568848,explained_var_old:0.419,explained_var_new:0.531
# batch i:416, episode_len:9
# kl:0.03969,lr_multiplier:0.444,loss:2.7092034816741943,entropy:2.3288581371307373,explained_var_old:0.429,explained_var_new:0.559
# batch i:417, episode_len:13
# kl:0.03872,lr_multiplier:0.444,loss:2.7631256580352783,entropy:2.314028024673462,explained_var_old:0.420,explained_var_new:0.571
# batch i:418, episode_len:12
# kl:0.02748,lr_multiplier:0.444,loss:2.8495960235595703,entropy:2.325615406036377,explained_var_old:0.374,explained_var_new:0.488
# batch i:419, episode_len:10
# kl:0.02152,lr_multiplier:0.444,loss:2.693660020828247,entropy:2.2127389907836914,explained_var_old:0.329,explained_var_new:0.448
# batch i:420, episode_len:7
# kl:0.02938,lr_multiplier:0.444,loss:2.7988853454589844,entropy:2.3075125217437744,explained_var_old:0.420,explained_var_new:0.528
# batch i:421, episode_len:7
# kl:0.03924,lr_multiplier:0.444,loss:2.808338165283203,entropy:2.2363367080688477,explained_var_old:0.324,explained_var_new:0.450
# batch i:422, episode_len:18
# kl:0.02776,lr_multiplier:0.444,loss:2.7356276512145996,entropy:2.2499871253967285,explained_var_old:0.386,explained_var_new:0.500
# batch i:423, episode_len:7
# kl:0.02323,lr_multiplier:0.444,loss:2.9762628078460693,entropy:2.408573627471924,explained_var_old:0.340,explained_var_new:0.439
# batch i:424, episode_len:7
# kl:0.02432,lr_multiplier:0.444,loss:2.758340358734131,entropy:2.3019959926605225,explained_var_old:0.392,explained_var_new:0.525
# batch i:425, episode_len:11
# kl:0.02468,lr_multiplier:0.444,loss:2.634807825088501,entropy:2.1777005195617676,explained_var_old:0.462,explained_var_new:0.576
# batch i:426, episode_len:7
# kl:0.02703,lr_multiplier:0.444,loss:2.694636344909668,entropy:2.2520458698272705,explained_var_old:0.410,explained_var_new:0.535
# batch i:427, episode_len:7
# kl:0.02635,lr_multiplier:0.444,loss:2.697740316390991,entropy:2.2556228637695312,explained_var_old:0.449,explained_var_new:0.560
# batch i:428, episode_len:7
# kl:0.02551,lr_multiplier:0.444,loss:2.704409599304199,entropy:2.248310089111328,explained_var_old:0.437,explained_var_new:0.552
# batch i:429, episode_len:11
# kl:0.02531,lr_multiplier:0.444,loss:2.7311604022979736,entropy:2.260570526123047,explained_var_old:0.376,explained_var_new:0.534
# batch i:430, episode_len:14
# kl:0.03018,lr_multiplier:0.444,loss:2.6650631427764893,entropy:2.276991844177246,explained_var_old:0.460,explained_var_new:0.578
# batch i:431, episode_len:11
# kl:0.02426,lr_multiplier:0.444,loss:2.5976767539978027,entropy:2.1324634552001953,explained_var_old:0.405,explained_var_new:0.523
# batch i:432, episode_len:9
# kl:0.02694,lr_multiplier:0.444,loss:2.7389273643493652,entropy:2.219189405441284,explained_var_old:0.404,explained_var_new:0.549
# batch i:433, episode_len:13
# kl:0.02690,lr_multiplier:0.444,loss:2.7175111770629883,entropy:2.279858112335205,explained_var_old:0.466,explained_var_new:0.557
# batch i:434, episode_len:8
# kl:0.01935,lr_multiplier:0.444,loss:2.714237928390503,entropy:2.2633779048919678,explained_var_old:0.378,explained_var_new:0.509
# batch i:435, episode_len:9
# kl:0.02841,lr_multiplier:0.444,loss:2.628969430923462,entropy:2.2502331733703613,explained_var_old:0.455,explained_var_new:0.579
# batch i:436, episode_len:11
# kl:0.02654,lr_multiplier:0.444,loss:2.7757339477539062,entropy:2.2460501194000244,explained_var_old:0.474,explained_var_new:0.548
# batch i:437, episode_len:11
# kl:0.02272,lr_multiplier:0.444,loss:2.581104040145874,entropy:2.1564717292785645,explained_var_old:0.448,explained_var_new:0.569
# batch i:438, episode_len:9
# kl:0.02789,lr_multiplier:0.444,loss:2.6909923553466797,entropy:2.228250741958618,explained_var_old:0.366,explained_var_new:0.519
# batch i:439, episode_len:7
# kl:0.03163,lr_multiplier:0.444,loss:2.635317802429199,entropy:2.1811161041259766,explained_var_old:0.478,explained_var_new:0.576
# batch i:440, episode_len:7
# kl:0.02542,lr_multiplier:0.444,loss:2.667747974395752,entropy:2.144768238067627,explained_var_old:0.374,explained_var_new:0.506
# batch i:441, episode_len:8
# kl:0.02423,lr_multiplier:0.444,loss:2.577658176422119,entropy:2.249070167541504,explained_var_old:0.474,explained_var_new:0.596
# batch i:442, episode_len:12
# kl:0.01992,lr_multiplier:0.444,loss:2.7008824348449707,entropy:2.179997205734253,explained_var_old:0.351,explained_var_new:0.486
# batch i:443, episode_len:15
# kl:0.02012,lr_multiplier:0.444,loss:2.8240747451782227,entropy:2.265634059906006,explained_var_old:0.343,explained_var_new:0.479
# batch i:444, episode_len:14
# kl:0.02195,lr_multiplier:0.444,loss:2.6815216541290283,entropy:2.2456440925598145,explained_var_old:0.447,explained_var_new:0.566
# batch i:445, episode_len:7
# kl:0.02637,lr_multiplier:0.444,loss:2.6438021659851074,entropy:2.2318308353424072,explained_var_old:0.497,explained_var_new:0.588
# batch i:446, episode_len:14
# kl:0.02822,lr_multiplier:0.444,loss:2.6296277046203613,entropy:2.1164498329162598,explained_var_old:0.413,explained_var_new:0.501
# batch i:447, episode_len:7
# kl:0.02481,lr_multiplier:0.444,loss:2.6786415576934814,entropy:2.2785491943359375,explained_var_old:0.499,explained_var_new:0.575
# batch i:448, episode_len:8
# kl:0.02302,lr_multiplier:0.444,loss:2.556037425994873,entropy:2.162792682647705,explained_var_old:0.501,explained_var_new:0.595
# batch i:449, episode_len:7
# kl:0.01824,lr_multiplier:0.444,loss:2.6850860118865967,entropy:2.1892459392547607,explained_var_old:0.468,explained_var_new:0.569
# batch i:450, episode_len:12
# kl:0.01981,lr_multiplier:0.444,loss:2.576340675354004,entropy:2.1587040424346924,explained_var_old:0.453,explained_var_new:0.568
# current self-play batch: 450
# num_playouts:1000, win: 8, lose: 2, tie:0
# batch i:451, episode_len:11
# kl:0.02676,lr_multiplier:0.444,loss:2.681612014770508,entropy:2.1989223957061768,explained_var_old:0.407,explained_var_new:0.538
# batch i:452, episode_len:8
# kl:0.02694,lr_multiplier:0.444,loss:2.6747403144836426,entropy:2.219799280166626,explained_var_old:0.431,explained_var_new:0.562
# batch i:453, episode_len:8
# kl:0.02140,lr_multiplier:0.444,loss:2.621185064315796,entropy:2.203678607940674,explained_var_old:0.439,explained_var_new:0.541
# batch i:454, episode_len:7
# kl:0.02338,lr_multiplier:0.444,loss:2.5490615367889404,entropy:2.13132643699646,explained_var_old:0.530,explained_var_new:0.630
# batch i:455, episode_len:7
# kl:0.02232,lr_multiplier:0.444,loss:2.6317851543426514,entropy:2.2569103240966797,explained_var_old:0.512,explained_var_new:0.610
# batch i:456, episode_len:10
# kl:0.02961,lr_multiplier:0.444,loss:2.6213574409484863,entropy:2.2227120399475098,explained_var_old:0.542,explained_var_new:0.639
# batch i:457, episode_len:7
# kl:0.01442,lr_multiplier:0.444,loss:2.63854718208313,entropy:2.2949790954589844,explained_var_old:0.497,explained_var_new:0.590
# batch i:458, episode_len:7
# kl:0.02723,lr_multiplier:0.444,loss:2.6927034854888916,entropy:2.201979398727417,explained_var_old:0.435,explained_var_new:0.568
# batch i:459, episode_len:16
# kl:0.02273,lr_multiplier:0.444,loss:2.6375908851623535,entropy:2.2883808612823486,explained_var_old:0.482,explained_var_new:0.606
# batch i:460, episode_len:11
# kl:0.01608,lr_multiplier:0.444,loss:2.7388501167297363,entropy:2.2873406410217285,explained_var_old:0.434,explained_var_new:0.540
# batch i:461, episode_len:18
# kl:0.01652,lr_multiplier:0.444,loss:2.5933969020843506,entropy:2.191129207611084,explained_var_old:0.484,explained_var_new:0.574
# batch i:462, episode_len:7
# kl:0.02466,lr_multiplier:0.444,loss:2.6406197547912598,entropy:2.177591323852539,explained_var_old:0.438,explained_var_new:0.542
# batch i:463, episode_len:8
# kl:0.01804,lr_multiplier:0.444,loss:2.654340982437134,entropy:2.1885552406311035,explained_var_old:0.475,explained_var_new:0.584
# batch i:464, episode_len:7
# kl:0.01693,lr_multiplier:0.444,loss:2.604210376739502,entropy:2.1794819831848145,explained_var_old:0.484,explained_var_new:0.576
# batch i:465, episode_len:7
# kl:0.02181,lr_multiplier:0.444,loss:2.790930986404419,entropy:2.3099842071533203,explained_var_old:0.425,explained_var_new:0.549
# batch i:466, episode_len:10
# kl:0.02084,lr_multiplier:0.444,loss:2.6554932594299316,entropy:2.1638717651367188,explained_var_old:0.396,explained_var_new:0.492
# batch i:467, episode_len:8
# kl:0.03381,lr_multiplier:0.444,loss:2.725874185562134,entropy:2.2725508213043213,explained_var_old:0.410,explained_var_new:0.521
# batch i:468, episode_len:10
# kl:0.03487,lr_multiplier:0.444,loss:2.677727222442627,entropy:2.144232749938965,explained_var_old:0.393,explained_var_new:0.521
# batch i:469, episode_len:12
# kl:0.02691,lr_multiplier:0.444,loss:2.6824493408203125,entropy:2.2340524196624756,explained_var_old:0.450,explained_var_new:0.559
# batch i:470, episode_len:9
# kl:0.01740,lr_multiplier:0.444,loss:2.501701593399048,entropy:2.1532435417175293,explained_var_old:0.549,explained_var_new:0.628
# batch i:471, episode_len:9
# kl:0.02018,lr_multiplier:0.444,loss:2.6842217445373535,entropy:2.2822604179382324,explained_var_old:0.486,explained_var_new:0.574
# batch i:472, episode_len:10
# kl:0.01980,lr_multiplier:0.444,loss:2.5520927906036377,entropy:2.1494789123535156,explained_var_old:0.520,explained_var_new:0.621
# batch i:473, episode_len:8
# kl:0.01932,lr_multiplier:0.444,loss:2.581488609313965,entropy:2.127676010131836,explained_var_old:0.464,explained_var_new:0.551
# batch i:474, episode_len:8
# kl:0.01908,lr_multiplier:0.444,loss:2.686091899871826,entropy:2.2741081714630127,explained_var_old:0.462,explained_var_new:0.579
# batch i:475, episode_len:7
# kl:0.01695,lr_multiplier:0.444,loss:2.6531805992126465,entropy:2.2947998046875,explained_var_old:0.548,explained_var_new:0.617
# batch i:476, episode_len:8
# kl:0.02194,lr_multiplier:0.444,loss:2.5500569343566895,entropy:2.146766185760498,explained_var_old:0.514,explained_var_new:0.607
# batch i:477, episode_len:9
# kl:0.01527,lr_multiplier:0.444,loss:2.7177629470825195,entropy:2.2743301391601562,explained_var_old:0.465,explained_var_new:0.555
# batch i:478, episode_len:10
# kl:0.02097,lr_multiplier:0.444,loss:2.522247076034546,entropy:2.176665782928467,explained_var_old:0.543,explained_var_new:0.629
# batch i:479, episode_len:9
# kl:0.01656,lr_multiplier:0.444,loss:2.6308000087738037,entropy:2.177974224090576,explained_var_old:0.495,explained_var_new:0.614
# batch i:480, episode_len:8
# kl:0.02946,lr_multiplier:0.444,loss:2.5235931873321533,entropy:2.211243152618408,explained_var_old:0.519,explained_var_new:0.629
# batch i:481, episode_len:9
# kl:0.02311,lr_multiplier:0.444,loss:2.707305431365967,entropy:2.280381202697754,explained_var_old:0.515,explained_var_new:0.637
# batch i:482, episode_len:9
# kl:0.02442,lr_multiplier:0.444,loss:2.543327808380127,entropy:2.1476049423217773,explained_var_old:0.498,explained_var_new:0.590
# batch i:483, episode_len:13
# kl:0.02212,lr_multiplier:0.444,loss:2.5023036003112793,entropy:2.152716636657715,explained_var_old:0.509,explained_var_new:0.619
# batch i:484, episode_len:10
# kl:0.02165,lr_multiplier:0.444,loss:2.5379090309143066,entropy:2.131338119506836,explained_var_old:0.519,explained_var_new:0.603
# batch i:485, episode_len:11
# kl:0.02230,lr_multiplier:0.444,loss:2.6225204467773438,entropy:2.1746864318847656,explained_var_old:0.506,explained_var_new:0.588
# batch i:486, episode_len:9
# kl:0.02903,lr_multiplier:0.444,loss:2.6470820903778076,entropy:2.280829429626465,explained_var_old:0.515,explained_var_new:0.612
# batch i:487, episode_len:8
# kl:0.01701,lr_multiplier:0.444,loss:2.6091907024383545,entropy:2.2303497791290283,explained_var_old:0.510,explained_var_new:0.596
# batch i:488, episode_len:8
# kl:0.02917,lr_multiplier:0.444,loss:2.626192092895508,entropy:2.1929283142089844,explained_var_old:0.515,explained_var_new:0.609
# batch i:489, episode_len:7
# kl:0.01851,lr_multiplier:0.444,loss:2.49713134765625,entropy:2.149872303009033,explained_var_old:0.557,explained_var_new:0.667
# batch i:490, episode_len:15
# kl:0.02412,lr_multiplier:0.444,loss:2.4973113536834717,entropy:2.125941038131714,explained_var_old:0.506,explained_var_new:0.599
# batch i:491, episode_len:9
# kl:0.02043,lr_multiplier:0.444,loss:2.626269578933716,entropy:2.20456600189209,explained_var_old:0.488,explained_var_new:0.589
# batch i:492, episode_len:9
# kl:0.01463,lr_multiplier:0.444,loss:2.571622610092163,entropy:2.160804271697998,explained_var_old:0.523,explained_var_new:0.611
# batch i:493, episode_len:10
# kl:0.02203,lr_multiplier:0.444,loss:2.4675025939941406,entropy:2.2013182640075684,explained_var_old:0.586,explained_var_new:0.679
# batch i:494, episode_len:7
# kl:0.02068,lr_multiplier:0.444,loss:2.472252130508423,entropy:2.09299373626709,explained_var_old:0.514,explained_var_new:0.613
# batch i:495, episode_len:8
# kl:0.02775,lr_multiplier:0.444,loss:2.657930612564087,entropy:2.1998074054718018,explained_var_old:0.512,explained_var_new:0.592
# batch i:496, episode_len:7
# kl:0.02721,lr_multiplier:0.444,loss:2.54494309425354,entropy:2.264348030090332,explained_var_old:0.552,explained_var_new:0.634
# batch i:497, episode_len:13
# kl:0.02919,lr_multiplier:0.444,loss:2.499617099761963,entropy:2.0440101623535156,explained_var_old:0.549,explained_var_new:0.643
# batch i:498, episode_len:11
# kl:0.02015,lr_multiplier:0.444,loss:2.6064374446868896,entropy:2.212799549102783,explained_var_old:0.484,explained_var_new:0.581
# batch i:499, episode_len:8
# kl:0.02278,lr_multiplier:0.444,loss:2.5804965496063232,entropy:2.1836464405059814,explained_var_old:0.482,explained_var_new:0.596
# batch i:500, episode_len:7
# kl:0.01930,lr_multiplier:0.444,loss:2.5386953353881836,entropy:2.1853580474853516,explained_var_old:0.484,explained_var_new:0.600
# current self-play batch: 500
# num_playouts:1000, win: 9, lose: 1, tie:0

# %% [markdown]
# 250epoch的模型蠢得要死

# %%
# !python human_play.py
